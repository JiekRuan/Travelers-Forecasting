# %%
import pandas
import seaborn
import matplotlib.pyplot as plt
import numpy

# %%
path_csv = "D:/sklearn/linear_regression/number of travelers.csv"
dataset_df = pandas.read_csv(path_csv, sep=",")

# %%
dataset_df.head()
# Out:
#         month  passengers
# 0  2000-01-01       46492
# 1  2000-02-01       48526
# 2  2000-03-01       58764
# 3  2000-04-01       56033
# 4  2000-05-01       58201

# %%
plt.figure(figsize=(15, 6))
seaborn.scatterplot(x="month", y="passengers", data=dataset_df)
plt.show()

# %%
dataset_df["index_time"] = numpy.arange(1, len(dataset_df)+1, 1)

# %%
dataset_df
# Out:
#           month  passengers  index_time
# 0    2000-01-01       46492           1
# 1    2000-02-01       48526           2
# 2    2000-03-01       58764           3
# 3    2000-04-01       56033           4
# 4    2000-05-01       58201           5
# ..          ...         ...         ...
# 235  2019-08-01       83784         236
# 236  2019-09-01       72590         237
# 237  2019-10-01       78617         238
# 238  2019-11-01       73074         239
# 239  2019-12-01       79302         240
#
# [240 rows x 3 columns]

# %%
dataset_lenght = len(dataset_df)
index_plit = int(dataset_lenght*0.8)
train_df = dataset_df.loc[:index_split]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 dataset_lenght = len(dataset_df)
#       2 index_plit = int(dataset_lenght*0.8)
# ----> 3 train_df = dataset_df.loc[:index_split]
#
# NameError: name 'index_split' is not defined
